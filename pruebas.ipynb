# %%
import pandas as pd

df = pd.read_csv("data/raw/olist_orders_dataset.csv")

df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
import os
print("cwd:", os.getcwd())
print("exists file:", os.path.exists("data/raw/olist_orders_dataset.csv"))
print("raw dir listing:", os.listdir("data/raw") if os.path.exists("data/raw") else "data/raw not found")
# Out:
# cwd: /home/david/Desktop/ecommerce-analytics/python
# exists file: False
# raw dir listing: data/raw not found
